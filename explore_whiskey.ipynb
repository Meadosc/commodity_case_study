# %% [markdown]
# # Whiskey Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from helper.helper import comm_loc_df
from helper.helper import miss_years
from helper.helper import df_plot

# %%
df_wsky = comm_loc_df("Whiskey", "San Francisco")
print(f"Missing years: {miss_years(df_wsky)}")
fig, ax = df_plot(df_wsky)
# Out:
# Missing years: none
